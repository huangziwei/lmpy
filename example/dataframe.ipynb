# %%
import hea

import numpy as np
import polars as pl

# %% [markdown]
# ## Examples from *R for Data Science* (2023)

# %% [markdown]
# ### Chapter 3

# %%
flights = hea.data("flights", package="nycflights13")
flights
# Out:
# shape: (336_776, 19)
# ┌──────┬───────┬─────┬──────────┬───┬──────────┬──────┬────────┬──────────────────────┐
# │ year ┆ month ┆ day ┆ dep_time ┆ … ┆ distance ┆ hour ┆ minute ┆ time_hour            │
# │ ---  ┆ ---   ┆ --- ┆ ---      ┆   ┆ ---      ┆ ---  ┆ ---    ┆ ---                  │
# │ i64  ┆ i64   ┆ i64 ┆ f64      ┆   ┆ i64      ┆ i64  ┆ i64    ┆ str                  │
# ╞══════╪═══════╪═════╪══════════╪═══╪══════════╪══════╪════════╪══════════════════════╡
# │ 2013 ┆ 1     ┆ 1   ┆ 517.0    ┆ … ┆ 1400     ┆ 5    ┆ 15     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 533.0    ┆ … ┆ 1416     ┆ 5    ┆ 29     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 542.0    ┆ … ┆ 1089     ┆ 5    ┆ 40     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 544.0    ┆ … ┆ 1576     ┆ 5    ┆ 45     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 554.0    ┆ … ┆ 762      ┆ 6    ┆ 0      ┆ 2013-01-01T11:00:00Z │
# ...

# %%
out = (
      flights.filter(pl.col("dest") == "IAH")
             .group_by("year", "month", "day")
             .summarize(
                arr_delay=pl.col("arr_delay").mean()
             )
  )

# %%
out
# Out:
# shape: (365, 4)
# ┌──────┬───────┬─────┬────────────┐
# │ year ┆ month ┆ day ┆ arr_delay  │
# │ ---  ┆ ---   ┆ --- ┆ ---        │
# │ i64  ┆ i64   ┆ i64 ┆ f64        │
# ╞══════╪═══════╪═════╪════════════╡
# │ 2013 ┆ 1     ┆ 1   ┆ 17.85      │
# │ 2013 ┆ 1     ┆ 2   ┆ 7.0        │
# │ 2013 ┆ 1     ┆ 3   ┆ 18.315789  │
# │ 2013 ┆ 1     ┆ 4   ┆ -3.2       │
# │ 2013 ┆ 1     ┆ 5   ┆ 20.230769  │
# │ …    ┆ …     ┆ …   ┆ …          │
# │ 2013 ┆ 9     ┆ 26  ┆ -16.857143 │
# │ 2013 ┆ 9     ┆ 27  ┆ -26.545455 │
# │ 2013 ┆ 9     ┆ 28  ┆ -27.133333 │
# │ 2013 ┆ 9     ┆ 29  ┆ 0.333333   │
# │ 2013 ┆ 9     ┆ 30  ┆ -13.904762 │
# └──────┴───────┴─────┴────────────┘

# %%
flights.filter(pl.col("dep_delay") > 120)
# Out:
# shape: (9_723, 19)
# ┌──────┬───────┬─────┬──────────┬───┬──────────┬──────┬────────┬──────────────────────┐
# │ year ┆ month ┆ day ┆ dep_time ┆ … ┆ distance ┆ hour ┆ minute ┆ time_hour            │
# │ ---  ┆ ---   ┆ --- ┆ ---      ┆   ┆ ---      ┆ ---  ┆ ---    ┆ ---                  │
# │ i64  ┆ i64   ┆ i64 ┆ f64      ┆   ┆ i64      ┆ i64  ┆ i64    ┆ str                  │
# ╞══════╪═══════╪═════╪══════════╪═══╪══════════╪══════╪════════╪══════════════════════╡
# │ 2013 ┆ 1     ┆ 1   ┆ 848.0    ┆ … ┆ 184      ┆ 18   ┆ 35     ┆ 2013-01-01T23:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 957.0    ┆ … ┆ 200      ┆ 7    ┆ 33     ┆ 2013-01-01T12:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 1114.0   ┆ … ┆ 1416     ┆ 9    ┆ 0      ┆ 2013-01-01T14:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 1540.0   ┆ … ┆ 1598     ┆ 13   ┆ 38     ┆ 2013-01-01T18:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 1815.0   ┆ … ┆ 1134     ┆ 13   ┆ 25     ┆ 2013-01-01T18:00:00Z │
# ...

# %%
flights.filter((pl.col("month") == 1) & (pl.col("day") == 1))
# Out:
# shape: (842, 19)
# ┌──────┬───────┬─────┬──────────┬───┬──────────┬──────┬────────┬──────────────────────┐
# │ year ┆ month ┆ day ┆ dep_time ┆ … ┆ distance ┆ hour ┆ minute ┆ time_hour            │
# │ ---  ┆ ---   ┆ --- ┆ ---      ┆   ┆ ---      ┆ ---  ┆ ---    ┆ ---                  │
# │ i64  ┆ i64   ┆ i64 ┆ f64      ┆   ┆ i64      ┆ i64  ┆ i64    ┆ str                  │
# ╞══════╪═══════╪═════╪══════════╪═══╪══════════╪══════╪════════╪══════════════════════╡
# │ 2013 ┆ 1     ┆ 1   ┆ 517.0    ┆ … ┆ 1400     ┆ 5    ┆ 15     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 533.0    ┆ … ┆ 1416     ┆ 5    ┆ 29     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 542.0    ┆ … ┆ 1089     ┆ 5    ┆ 40     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 544.0    ┆ … ┆ 1576     ┆ 5    ┆ 45     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 554.0    ┆ … ┆ 762      ┆ 6    ┆ 0      ┆ 2013-01-01T11:00:00Z │
# ...

# %%
flights.filter((pl.col("month") == 1) | (pl.col("month") == 2))
# Out:
# shape: (51_955, 19)
# ┌──────┬───────┬─────┬──────────┬───┬──────────┬──────┬────────┬──────────────────────┐
# │ year ┆ month ┆ day ┆ dep_time ┆ … ┆ distance ┆ hour ┆ minute ┆ time_hour            │
# │ ---  ┆ ---   ┆ --- ┆ ---      ┆   ┆ ---      ┆ ---  ┆ ---    ┆ ---                  │
# │ i64  ┆ i64   ┆ i64 ┆ f64      ┆   ┆ i64      ┆ i64  ┆ i64    ┆ str                  │
# ╞══════╪═══════╪═════╪══════════╪═══╪══════════╪══════╪════════╪══════════════════════╡
# │ 2013 ┆ 1     ┆ 1   ┆ 517.0    ┆ … ┆ 1400     ┆ 5    ┆ 15     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 533.0    ┆ … ┆ 1416     ┆ 5    ┆ 29     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 542.0    ┆ … ┆ 1089     ┆ 5    ┆ 40     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 544.0    ┆ … ┆ 1576     ┆ 5    ┆ 45     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 554.0    ┆ … ┆ 762      ┆ 6    ┆ 0      ┆ 2013-01-01T11:00:00Z │
# ...

# %%
flights.filter(pl.col("month").is_in([1, 2]))
# Out:
# shape: (51_955, 19)
# ┌──────┬───────┬─────┬──────────┬───┬──────────┬──────┬────────┬──────────────────────┐
# │ year ┆ month ┆ day ┆ dep_time ┆ … ┆ distance ┆ hour ┆ minute ┆ time_hour            │
# │ ---  ┆ ---   ┆ --- ┆ ---      ┆   ┆ ---      ┆ ---  ┆ ---    ┆ ---                  │
# │ i64  ┆ i64   ┆ i64 ┆ f64      ┆   ┆ i64      ┆ i64  ┆ i64    ┆ str                  │
# ╞══════╪═══════╪═════╪══════════╪═══╪══════════╪══════╪════════╪══════════════════════╡
# │ 2013 ┆ 1     ┆ 1   ┆ 517.0    ┆ … ┆ 1400     ┆ 5    ┆ 15     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 533.0    ┆ … ┆ 1416     ┆ 5    ┆ 29     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 542.0    ┆ … ┆ 1089     ┆ 5    ┆ 40     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 544.0    ┆ … ┆ 1576     ┆ 5    ┆ 45     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 554.0    ┆ … ┆ 762      ┆ 6    ┆ 0      ┆ 2013-01-01T11:00:00Z │
# ...

# %%
jan1 = flights.filter(pl.col("month") == 1, pl.col("day") == 1)

# %%
jan1
# Out:
# shape: (842, 19)
# ┌──────┬───────┬─────┬──────────┬───┬──────────┬──────┬────────┬──────────────────────┐
# │ year ┆ month ┆ day ┆ dep_time ┆ … ┆ distance ┆ hour ┆ minute ┆ time_hour            │
# │ ---  ┆ ---   ┆ --- ┆ ---      ┆   ┆ ---      ┆ ---  ┆ ---    ┆ ---                  │
# │ i64  ┆ i64   ┆ i64 ┆ f64      ┆   ┆ i64      ┆ i64  ┆ i64    ┆ str                  │
# ╞══════╪═══════╪═════╪══════════╪═══╪══════════╪══════╪════════╪══════════════════════╡
# │ 2013 ┆ 1     ┆ 1   ┆ 517.0    ┆ … ┆ 1400     ┆ 5    ┆ 15     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 533.0    ┆ … ┆ 1416     ┆ 5    ┆ 29     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 542.0    ┆ … ┆ 1089     ┆ 5    ┆ 40     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 544.0    ┆ … ┆ 1576     ┆ 5    ┆ 45     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 554.0    ┆ … ┆ 762      ┆ 6    ┆ 0      ┆ 2013-01-01T11:00:00Z │
# ...

# %%
flights.arrange("year", "month", "day", "dep_time")
# Out:
# shape: (336_776, 19)
# ┌──────┬───────┬─────┬──────────┬───┬──────────┬──────┬────────┬──────────────────────┐
# │ year ┆ month ┆ day ┆ dep_time ┆ … ┆ distance ┆ hour ┆ minute ┆ time_hour            │
# │ ---  ┆ ---   ┆ --- ┆ ---      ┆   ┆ ---      ┆ ---  ┆ ---    ┆ ---                  │
# │ i64  ┆ i64   ┆ i64 ┆ f64      ┆   ┆ i64      ┆ i64  ┆ i64    ┆ str                  │
# ╞══════╪═══════╪═════╪══════════╪═══╪══════════╪══════╪════════╪══════════════════════╡
# │ 2013 ┆ 1     ┆ 1   ┆ 517.0    ┆ … ┆ 1400     ┆ 5    ┆ 15     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 533.0    ┆ … ┆ 1416     ┆ 5    ┆ 29     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 542.0    ┆ … ┆ 1089     ┆ 5    ┆ 40     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 544.0    ┆ … ┆ 1576     ┆ 5    ┆ 45     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 554.0    ┆ … ┆ 762      ┆ 6    ┆ 0      ┆ 2013-01-01T11:00:00Z │
# ...

# %%
flights.arrange(pl.desc("dep_delay"))
# Out:
# shape: (336_776, 19)
# ┌──────┬───────┬─────┬──────────┬───┬──────────┬──────┬────────┬──────────────────────┐
# │ year ┆ month ┆ day ┆ dep_time ┆ … ┆ distance ┆ hour ┆ minute ┆ time_hour            │
# │ ---  ┆ ---   ┆ --- ┆ ---      ┆   ┆ ---      ┆ ---  ┆ ---    ┆ ---                  │
# │ i64  ┆ i64   ┆ i64 ┆ f64      ┆   ┆ i64      ┆ i64  ┆ i64    ┆ str                  │
# ╞══════╪═══════╪═════╪══════════╪═══╪══════════╪══════╪════════╪══════════════════════╡
# │ 2013 ┆ 1     ┆ 9   ┆ 641.0    ┆ … ┆ 4983     ┆ 9    ┆ 0      ┆ 2013-01-09T14:00:00Z │
# │ 2013 ┆ 6     ┆ 15  ┆ 1432.0   ┆ … ┆ 483      ┆ 19   ┆ 35     ┆ 2013-06-15T23:00:00Z │
# │ 2013 ┆ 1     ┆ 10  ┆ 1121.0   ┆ … ┆ 719      ┆ 16   ┆ 35     ┆ 2013-01-10T21:00:00Z │
# │ 2013 ┆ 9     ┆ 20  ┆ 1139.0   ┆ … ┆ 2586     ┆ 18   ┆ 45     ┆ 2013-09-20T22:00:00Z │
# │ 2013 ┆ 7     ┆ 22  ┆ 845.0    ┆ … ┆ 589      ┆ 16   ┆ 0      ┆ 2013-07-22T20:00:00Z │
# ...

# %%
flights.distinct()
# Out:
# shape: (336_776, 19)
# ┌──────┬───────┬─────┬──────────┬───┬──────────┬──────┬────────┬──────────────────────┐
# │ year ┆ month ┆ day ┆ dep_time ┆ … ┆ distance ┆ hour ┆ minute ┆ time_hour            │
# │ ---  ┆ ---   ┆ --- ┆ ---      ┆   ┆ ---      ┆ ---  ┆ ---    ┆ ---                  │
# │ i64  ┆ i64   ┆ i64 ┆ f64      ┆   ┆ i64      ┆ i64  ┆ i64    ┆ str                  │
# ╞══════╪═══════╪═════╪══════════╪═══╪══════════╪══════╪════════╪══════════════════════╡
# │ 2013 ┆ 1     ┆ 1   ┆ 517.0    ┆ … ┆ 1400     ┆ 5    ┆ 15     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 533.0    ┆ … ┆ 1416     ┆ 5    ┆ 29     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 542.0    ┆ … ┆ 1089     ┆ 5    ┆ 40     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 544.0    ┆ … ┆ 1576     ┆ 5    ┆ 45     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 554.0    ┆ … ┆ 762      ┆ 6    ┆ 0      ┆ 2013-01-01T11:00:00Z │
# ...

# %%
flights.distinct("origin", "dest")
# Out:
# shape: (224, 2)
# ┌────────┬──────┐
# │ origin ┆ dest │
# │ ---    ┆ ---  │
# │ str    ┆ str  │
# ╞════════╪══════╡
# │ EWR    ┆ IAH  │
# │ LGA    ┆ IAH  │
# │ JFK    ┆ MIA  │
# │ JFK    ┆ BQN  │
# │ LGA    ┆ ATL  │
# │ …      ┆ …    │
# │ LGA    ┆ TVC  │
# │ LGA    ┆ MYR  │
# │ EWR    ┆ TVC  │
# │ EWR    ┆ ANC  │
# │ EWR    ┆ LGA  │
# └────────┴──────┘

# %%
flights.distinct("origin", "dest", keep_all=True)
# Out:
# shape: (224, 19)
# ┌──────┬───────┬─────┬──────────┬───┬──────────┬──────┬────────┬──────────────────────┐
# │ year ┆ month ┆ day ┆ dep_time ┆ … ┆ distance ┆ hour ┆ minute ┆ time_hour            │
# │ ---  ┆ ---   ┆ --- ┆ ---      ┆   ┆ ---      ┆ ---  ┆ ---    ┆ ---                  │
# │ i64  ┆ i64   ┆ i64 ┆ f64      ┆   ┆ i64      ┆ i64  ┆ i64    ┆ str                  │
# ╞══════╪═══════╪═════╪══════════╪═══╪══════════╪══════╪════════╪══════════════════════╡
# │ 2013 ┆ 1     ┆ 1   ┆ 517.0    ┆ … ┆ 1400     ┆ 5    ┆ 15     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 533.0    ┆ … ┆ 1416     ┆ 5    ┆ 29     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 542.0    ┆ … ┆ 1089     ┆ 5    ┆ 40     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 544.0    ┆ … ┆ 1576     ┆ 5    ┆ 45     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 554.0    ┆ … ┆ 762      ┆ 6    ┆ 0      ┆ 2013-01-01T11:00:00Z │
# ...

# %%
flights.mutate(
    gain=pl.col("dep_delay") - pl.col("arr_delay"),
    speed=pl.col("distance") / pl.col("air_time") * 60,
)
# Out:
# shape: (336_776, 21)
# ┌──────┬───────┬─────┬──────────┬───┬────────┬──────────────────────┬───────┬────────────┐
# │ year ┆ month ┆ day ┆ dep_time ┆ … ┆ minute ┆ time_hour            ┆ gain  ┆ speed      │
# │ ---  ┆ ---   ┆ --- ┆ ---      ┆   ┆ ---    ┆ ---                  ┆ ---   ┆ ---        │
# │ i64  ┆ i64   ┆ i64 ┆ f64      ┆   ┆ i64    ┆ str                  ┆ f64   ┆ f64        │
# ╞══════╪═══════╪═════╪══════════╪═══╪════════╪══════════════════════╪═══════╪════════════╡
# │ 2013 ┆ 1     ┆ 1   ┆ 517.0    ┆ … ┆ 15     ┆ 2013-01-01T10:00:00Z ┆ -9.0  ┆ 370.044053 │
# │ 2013 ┆ 1     ┆ 1   ┆ 533.0    ┆ … ┆ 29     ┆ 2013-01-01T10:00:00Z ┆ -16.0 ┆ 374.273128 │
# │ 2013 ┆ 1     ┆ 1   ┆ 542.0    ┆ … ┆ 40     ┆ 2013-01-01T10:00:00Z ┆ -31.0 ┆ 408.375    │
# │ 2013 ┆ 1     ┆ 1   ┆ 544.0    ┆ … ┆ 45     ┆ 2013-01-01T10:00:00Z ┆ 17.0  ┆ 516.721311 │
# │ 2013 ┆ 1     ┆ 1   ┆ 554.0    ┆ … ┆ 0      ┆ 2013-01-01T11:00:00Z ┆ 19.0  ┆ 394.137931 │
# ...

# %%
flights.mutate(
    gain=pl.col("dep_delay") - pl.col("arr_delay"),
    speed=pl.col("distance") / pl.col("air_time") * 60,
    _before=1,
)
# Out:
# shape: (336_776, 21)
# ┌───────┬────────────┬──────┬───────┬───┬──────────┬──────┬────────┬──────────────────────┐
# │ gain  ┆ speed      ┆ year ┆ month ┆ … ┆ distance ┆ hour ┆ minute ┆ time_hour            │
# │ ---   ┆ ---        ┆ ---  ┆ ---   ┆   ┆ ---      ┆ ---  ┆ ---    ┆ ---                  │
# │ f64   ┆ f64        ┆ i64  ┆ i64   ┆   ┆ i64      ┆ i64  ┆ i64    ┆ str                  │
# ╞═══════╪════════════╪══════╪═══════╪═══╪══════════╪══════╪════════╪══════════════════════╡
# │ -9.0  ┆ 370.044053 ┆ 2013 ┆ 1     ┆ … ┆ 1400     ┆ 5    ┆ 15     ┆ 2013-01-01T10:00:00Z │
# │ -16.0 ┆ 374.273128 ┆ 2013 ┆ 1     ┆ … ┆ 1416     ┆ 5    ┆ 29     ┆ 2013-01-01T10:00:00Z │
# │ -31.0 ┆ 408.375    ┆ 2013 ┆ 1     ┆ … ┆ 1089     ┆ 5    ┆ 40     ┆ 2013-01-01T10:00:00Z │
# │ 17.0  ┆ 516.721311 ┆ 2013 ┆ 1     ┆ … ┆ 1576     ┆ 5    ┆ 45     ┆ 2013-01-01T10:00:00Z │
# │ 19.0  ┆ 394.137931 ┆ 2013 ┆ 1     ┆ … ┆ 762      ┆ 6    ┆ 0      ┆ 2013-01-01T11:00:00Z │
# ...

# %%
flights.mutate(
    gain=pl.col("dep_delay") - pl.col("arr_delay"),
    speed=pl.col("distance") / pl.col("air_time") * 60,
    _after="day"
)
# Out:
# shape: (336_776, 21)
# ┌──────┬───────┬─────┬───────┬───┬──────────┬──────┬────────┬──────────────────────┐
# │ year ┆ month ┆ day ┆ gain  ┆ … ┆ distance ┆ hour ┆ minute ┆ time_hour            │
# │ ---  ┆ ---   ┆ --- ┆ ---   ┆   ┆ ---      ┆ ---  ┆ ---    ┆ ---                  │
# │ i64  ┆ i64   ┆ i64 ┆ f64   ┆   ┆ i64      ┆ i64  ┆ i64    ┆ str                  │
# ╞══════╪═══════╪═════╪═══════╪═══╪══════════╪══════╪════════╪══════════════════════╡
# │ 2013 ┆ 1     ┆ 1   ┆ -9.0  ┆ … ┆ 1400     ┆ 5    ┆ 15     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ -16.0 ┆ … ┆ 1416     ┆ 5    ┆ 29     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ -31.0 ┆ … ┆ 1089     ┆ 5    ┆ 40     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 17.0  ┆ … ┆ 1576     ┆ 5    ┆ 45     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 19.0  ┆ … ┆ 762      ┆ 6    ┆ 0      ┆ 2013-01-01T11:00:00Z │
# │ …    ┆ …     ┆ …   ┆ …     ┆ … ┆ …        ┆ …    ┆ …      ┆ …                    │
# ...

# %%
flights.mutate(
    gain = pl.col("dep_delay") - pl.col("arr_delay"),
    hours = pl.col("air_time") / 60,
    gain_per_hour = pl.col("gain") / pl.col("hours"),
    _keep="used"
)
# Out:
# shape: (336_776, 6)
# ┌───────────┬───────────┬──────────┬───────┬──────────┬───────────────┐
# │ dep_delay ┆ arr_delay ┆ air_time ┆ gain  ┆ hours    ┆ gain_per_hour │
# │ ---       ┆ ---       ┆ ---      ┆ ---   ┆ ---      ┆ ---           │
# │ f64       ┆ f64       ┆ f64      ┆ f64   ┆ f64      ┆ f64           │
# ╞═══════════╪═══════════╪══════════╪═══════╪══════════╪═══════════════╡
# │ 2.0       ┆ 11.0      ┆ 227.0    ┆ -9.0  ┆ 3.783333 ┆ -2.378855     │
# │ 4.0       ┆ 20.0      ┆ 227.0    ┆ -16.0 ┆ 3.783333 ┆ -4.229075     │
# │ 2.0       ┆ 33.0      ┆ 160.0    ┆ -31.0 ┆ 2.666667 ┆ -11.625       │
# │ -1.0      ┆ -18.0     ┆ 183.0    ┆ 17.0  ┆ 3.05     ┆ 5.57377       │
# │ -6.0      ┆ -25.0     ┆ 116.0    ┆ 19.0  ┆ 1.933333 ┆ 9.827586      │
# │ …         ┆ …         ┆ …        ┆ …     ┆ …        ┆ …             │
# │ null      ┆ null      ┆ null     ┆ null  ┆ null     ┆ null          │
# │ null      ┆ null      ┆ null     ┆ null  ┆ null     ┆ null          │
# ...

# %%
flights.select("year", "month", "day")
# Out:
# shape: (336_776, 3)
# ┌──────┬───────┬─────┐
# │ year ┆ month ┆ day │
# │ ---  ┆ ---   ┆ --- │
# │ i64  ┆ i64   ┆ i64 │
# ╞══════╪═══════╪═════╡
# │ 2013 ┆ 1     ┆ 1   │
# │ 2013 ┆ 1     ┆ 1   │
# │ 2013 ┆ 1     ┆ 1   │
# │ 2013 ┆ 1     ┆ 1   │
# │ 2013 ┆ 1     ┆ 1   │
# │ …    ┆ …     ┆ …   │
# │ 2013 ┆ 9     ┆ 30  │
# │ 2013 ┆ 9     ┆ 30  │
# │ 2013 ┆ 9     ┆ 30  │
# │ 2013 ┆ 9     ┆ 30  │
# │ 2013 ┆ 9     ┆ 30  │
# └──────┴───────┴─────┘

# %%
flights.select(flights.cols_between("year", "day"))
# Out:
# shape: (336_776, 3)
# ┌──────┬───────┬─────┐
# │ year ┆ month ┆ day │
# │ ---  ┆ ---   ┆ --- │
# │ i64  ┆ i64   ┆ i64 │
# ╞══════╪═══════╪═════╡
# │ 2013 ┆ 1     ┆ 1   │
# │ 2013 ┆ 1     ┆ 1   │
# │ 2013 ┆ 1     ┆ 1   │
# │ 2013 ┆ 1     ┆ 1   │
# │ 2013 ┆ 1     ┆ 1   │
# │ …    ┆ …     ┆ …   │
# │ 2013 ┆ 9     ┆ 30  │
# │ 2013 ┆ 9     ┆ 30  │
# │ 2013 ┆ 9     ┆ 30  │
# │ 2013 ┆ 9     ┆ 30  │
# │ 2013 ┆ 9     ┆ 30  │
# └──────┴───────┴─────┘

# %%
flights.select(pl.exclude(flights.cols_between("year", "day")))
# Out:
# shape: (336_776, 16)
# ┌──────────┬────────────────┬───────────┬──────────┬───┬──────────┬──────┬────────┬────────────────┐
# │ dep_time ┆ sched_dep_time ┆ dep_delay ┆ arr_time ┆ … ┆ distance ┆ hour ┆ minute ┆ time_hour      │
# │ ---      ┆ ---            ┆ ---       ┆ ---      ┆   ┆ ---      ┆ ---  ┆ ---    ┆ ---            │
# │ f64      ┆ i64            ┆ f64       ┆ f64      ┆   ┆ i64      ┆ i64  ┆ i64    ┆ str            │
# ╞══════════╪════════════════╪═══════════╪══════════╪═══╪══════════╪══════╪════════╪════════════════╡
# │ 517.0    ┆ 515            ┆ 2.0       ┆ 830.0    ┆ … ┆ 1400     ┆ 5    ┆ 15     ┆ 2013-01-01T10: │
# │          ┆                ┆           ┆          ┆   ┆          ┆      ┆        ┆ 00:00Z         │
# │ 533.0    ┆ 529            ┆ 4.0       ┆ 850.0    ┆ … ┆ 1416     ┆ 5    ┆ 29     ┆ 2013-01-01T10: │
# │          ┆                ┆           ┆          ┆   ┆          ┆      ┆        ┆ 00:00Z         │
# ...

# %%
flights.select(pl.selectors.string())
# Out:
# shape: (336_776, 5)
# ┌─────────┬─────────┬────────┬──────┬──────────────────────┐
# │ carrier ┆ tailnum ┆ origin ┆ dest ┆ time_hour            │
# │ ---     ┆ ---     ┆ ---    ┆ ---  ┆ ---                  │
# │ str     ┆ str     ┆ str    ┆ str  ┆ str                  │
# ╞═════════╪═════════╪════════╪══════╪══════════════════════╡
# │ UA      ┆ N14228  ┆ EWR    ┆ IAH  ┆ 2013-01-01T10:00:00Z │
# │ UA      ┆ N24211  ┆ LGA    ┆ IAH  ┆ 2013-01-01T10:00:00Z │
# │ AA      ┆ N619AA  ┆ JFK    ┆ MIA  ┆ 2013-01-01T10:00:00Z │
# │ B6      ┆ N804JB  ┆ JFK    ┆ BQN  ┆ 2013-01-01T10:00:00Z │
# │ DL      ┆ N668DN  ┆ LGA    ┆ ATL  ┆ 2013-01-01T11:00:00Z │
# │ …       ┆ …       ┆ …      ┆ …    ┆ …                    │
# │ 9E      ┆ null    ┆ JFK    ┆ DCA  ┆ 2013-09-30T18:00:00Z │
# │ 9E      ┆ null    ┆ LGA    ┆ SYR  ┆ 2013-10-01T02:00:00Z │
# │ MQ      ┆ N535MQ  ┆ LGA    ┆ BNA  ┆ 2013-09-30T16:00:00Z │
# │ MQ      ┆ N511MQ  ┆ LGA    ┆ CLE  ┆ 2013-09-30T15:00:00Z │
# ...

# %%
flights.select(tail_num="tailnum")
# Out:
# shape: (336_776, 1)
# ┌──────────┐
# │ tail_num │
# │ ---      │
# │ str      │
# ╞══════════╡
# │ N14228   │
# │ N24211   │
# │ N619AA   │
# │ N804JB   │
# │ N668DN   │
# │ …        │
# │ null     │
# │ null     │
# │ N535MQ   │
# │ N511MQ   │
# │ N839MQ   │
# └──────────┘

# %%
np.vstack([flights.columns, flights.rename(tail_num="tailnum").columns]).T
# Out:
# array([['year', 'year'],
#        ['month', 'month'],
#        ['day', 'day'],
#        ['dep_time', 'dep_time'],
#        ['sched_dep_time', 'sched_dep_time'],
#        ['dep_delay', 'dep_delay'],
#        ['arr_time', 'arr_time'],
#        ['sched_arr_time', 'sched_arr_time'],
#        ['arr_delay', 'arr_delay'],
#        ['carrier', 'carrier'],
#        ['flight', 'flight'],
#        ['tailnum', 'tail_num'],
#        ['origin', 'origin'],
#        ['dest', 'dest'],
#        ['air_time', 'air_time'],
#        ['distance', 'distance'],
#        ['hour', 'hour'],
#        ['minute', 'minute'],
#        ['time_hour', 'time_hour']], dtype='<U14')

# %%
flights.relocate("time_hour", "air_time")
# Out:
# shape: (336_776, 19)
# ┌──────────┬──────────────────────┬──────┬───────┬───┬──────┬──────────┬──────┬────────┐
# │ air_time ┆ time_hour            ┆ year ┆ month ┆ … ┆ dest ┆ distance ┆ hour ┆ minute │
# │ ---      ┆ ---                  ┆ ---  ┆ ---   ┆   ┆ ---  ┆ ---      ┆ ---  ┆ ---    │
# │ f64      ┆ str                  ┆ i64  ┆ i64   ┆   ┆ str  ┆ i64      ┆ i64  ┆ i64    │
# ╞══════════╪══════════════════════╪══════╪═══════╪═══╪══════╪══════════╪══════╪════════╡
# │ 227.0    ┆ 2013-01-01T10:00:00Z ┆ 2013 ┆ 1     ┆ … ┆ IAH  ┆ 1400     ┆ 5    ┆ 15     │
# │ 227.0    ┆ 2013-01-01T10:00:00Z ┆ 2013 ┆ 1     ┆ … ┆ IAH  ┆ 1416     ┆ 5    ┆ 29     │
# │ 160.0    ┆ 2013-01-01T10:00:00Z ┆ 2013 ┆ 1     ┆ … ┆ MIA  ┆ 1089     ┆ 5    ┆ 40     │
# │ 183.0    ┆ 2013-01-01T10:00:00Z ┆ 2013 ┆ 1     ┆ … ┆ BQN  ┆ 1576     ┆ 5    ┆ 45     │
# │ 116.0    ┆ 2013-01-01T11:00:00Z ┆ 2013 ┆ 1     ┆ … ┆ ATL  ┆ 762      ┆ 6    ┆ 0      │
# ...

# %%
flights.relocate(flights.cols_between("year", "dep_time"), _after="time_hour")
# Out:
# shape: (336_776, 19)
# ┌────────────────┬───────────┬──────────┬────────────────┬───┬──────┬───────┬─────┬──────────┐
# │ sched_dep_time ┆ dep_delay ┆ arr_time ┆ sched_arr_time ┆ … ┆ year ┆ month ┆ day ┆ dep_time │
# │ ---            ┆ ---       ┆ ---      ┆ ---            ┆   ┆ ---  ┆ ---   ┆ --- ┆ ---      │
# │ i64            ┆ f64       ┆ f64      ┆ i64            ┆   ┆ i64  ┆ i64   ┆ i64 ┆ f64      │
# ╞════════════════╪═══════════╪══════════╪════════════════╪═══╪══════╪═══════╪═════╪══════════╡
# │ 515            ┆ 2.0       ┆ 830.0    ┆ 819            ┆ … ┆ 2013 ┆ 1     ┆ 1   ┆ 517.0    │
# │ 529            ┆ 4.0       ┆ 850.0    ┆ 830            ┆ … ┆ 2013 ┆ 1     ┆ 1   ┆ 533.0    │
# │ 540            ┆ 2.0       ┆ 923.0    ┆ 850            ┆ … ┆ 2013 ┆ 1     ┆ 1   ┆ 542.0    │
# │ 545            ┆ -1.0      ┆ 1004.0   ┆ 1022           ┆ … ┆ 2013 ┆ 1     ┆ 1   ┆ 544.0    │
# │ 600            ┆ -6.0      ┆ 812.0    ┆ 837            ┆ … ┆ 2013 ┆ 1     ┆ 1   ┆ 554.0    │
# ...

# %%
flights.relocate(pl.selectors.starts_with("arr"), _before="dep_time")
# Out:
# shape: (336_776, 19)
# ┌──────┬───────┬─────┬──────────┬───┬──────────┬──────┬────────┬──────────────────────┐
# │ year ┆ month ┆ day ┆ arr_time ┆ … ┆ distance ┆ hour ┆ minute ┆ time_hour            │
# │ ---  ┆ ---   ┆ --- ┆ ---      ┆   ┆ ---      ┆ ---  ┆ ---    ┆ ---                  │
# │ i64  ┆ i64   ┆ i64 ┆ f64      ┆   ┆ i64      ┆ i64  ┆ i64    ┆ str                  │
# ╞══════╪═══════╪═════╪══════════╪═══╪══════════╪══════╪════════╪══════════════════════╡
# │ 2013 ┆ 1     ┆ 1   ┆ 830.0    ┆ … ┆ 1400     ┆ 5    ┆ 15     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 850.0    ┆ … ┆ 1416     ┆ 5    ┆ 29     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 923.0    ┆ … ┆ 1089     ┆ 5    ┆ 40     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 1004.0   ┆ … ┆ 1576     ┆ 5    ┆ 45     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 812.0    ┆ … ┆ 762      ┆ 6    ┆ 0      ┆ 2013-01-01T11:00:00Z │
# ...

# %%
(
    flights
        .filter(pl.col("dest") == "IAH")
        .mutate(speed=pl.col("distance") / pl.col("air_time") * 60)
        .select(flights.cols_between("year", "day"), "dep_time", "carrier", "flight", "speed")
        .arrange(pl.desc("speed"))
)
# Out:
# shape: (7_198, 7)
# ┌──────┬───────┬─────┬──────────┬─────────┬────────┬────────────┐
# │ year ┆ month ┆ day ┆ dep_time ┆ carrier ┆ flight ┆ speed      │
# │ ---  ┆ ---   ┆ --- ┆ ---      ┆ ---     ┆ ---    ┆ ---        │
# │ i64  ┆ i64   ┆ i64 ┆ f64      ┆ str     ┆ i64    ┆ f64        │
# ╞══════╪═══════╪═════╪══════════╪═════════╪════════╪════════════╡
# │ 2013 ┆ 7     ┆ 9   ┆ 707.0    ┆ UA      ┆ 226    ┆ 521.73913  │
# │ 2013 ┆ 8     ┆ 27  ┆ 1850.0   ┆ UA      ┆ 1128   ┆ 521.226994 │
# │ 2013 ┆ 8     ┆ 28  ┆ 902.0    ┆ UA      ┆ 1711   ┆ 518.518519 │
# │ 2013 ┆ 8     ┆ 28  ┆ 2122.0   ┆ UA      ┆ 1022   ┆ 518.518519 │
# │ 2013 ┆ 6     ┆ 11  ┆ 1628.0   ┆ UA      ┆ 1178   ┆ 515.337423 │
# │ …    ┆ …     ┆ …   ┆ …        ┆ …       ┆ …      ┆ …          │
# │ 2013 ┆ 9     ┆ 12  ┆ 1815.0   ┆ UA      ┆ 1695   ┆ null       │
# │ 2013 ┆ 9     ┆ 12  ┆ null     ┆ UA      ┆ 404    ┆ null       │
# │ 2013 ┆ 9     ┆ 12  ┆ null     ┆ UA      ┆ 525    ┆ null       │
# ...

# %%
(
    flights
        .group_by("month")
        .summarize(
            avg_delay=pl.col("dep_delay").mean()
        )
)
# Out:
# shape: (12, 2)
# ┌───────┬───────────┐
# │ month ┆ avg_delay │
# │ ---   ┆ ---       │
# │ i64   ┆ f64       │
# ╞═══════╪═══════════╡
# │ 1     ┆ 10.036665 │
# │ 10    ┆ 6.243988  │
# │ 11    ┆ 5.435362  │
# │ 12    ┆ 16.576688 │
# │ 2     ┆ 10.816843 │
# │ …     ┆ …         │
# │ 5     ┆ 12.986859 │
# │ 6     ┆ 20.846332 │
# │ 7     ┆ 21.727787 │
# │ 8     ┆ 12.61104  │
# │ 9     ┆ 6.722476  │
# └───────┴───────────┘

# %%
(
    flights
        .group_by("month")
        .summarize(
            delay=pl.col("dep_delay").mean(),
            n=pl.len(),
        )
)
# Out:
# shape: (12, 3)
# ┌───────┬───────────┬───────┐
# │ month ┆ delay     ┆ n     │
# │ ---   ┆ ---       ┆ ---   │
# │ i64   ┆ f64       ┆ u32   │
# ╞═══════╪═══════════╪═══════╡
# │ 1     ┆ 10.036665 ┆ 27004 │
# │ 10    ┆ 6.243988  ┆ 28889 │
# │ 11    ┆ 5.435362  ┆ 27268 │
# │ 12    ┆ 16.576688 ┆ 28135 │
# │ 2     ┆ 10.816843 ┆ 24951 │
# │ …     ┆ …         ┆ …     │
# │ 5     ┆ 12.986859 ┆ 28796 │
# │ 6     ┆ 20.846332 ┆ 28243 │
# │ 7     ┆ 21.727787 ┆ 29425 │
# │ 8     ┆ 12.61104  ┆ 29327 │
# │ 9     ┆ 6.722476  ┆ 27574 │
# └───────┴───────────┴───────┘

# %%
(
    flights
        .group_by("dest")
        .slice_max("arr_delay", n=1)
        .relocate("dest")
)
# Out:
# shape: (108, 19)
# ┌──────┬──────┬───────┬─────┬───┬──────────┬──────┬────────┬──────────────────────┐
# │ dest ┆ year ┆ month ┆ day ┆ … ┆ distance ┆ hour ┆ minute ┆ time_hour            │
# │ ---  ┆ ---  ┆ ---   ┆ --- ┆   ┆ ---      ┆ ---  ┆ ---    ┆ ---                  │
# │ str  ┆ i64  ┆ i64   ┆ i64 ┆   ┆ i64      ┆ i64  ┆ i64    ┆ str                  │
# ╞══════╪══════╪═══════╪═════╪═══╪══════════╪══════╪════════╪══════════════════════╡
# │ ABQ  ┆ 2013 ┆ 7     ┆ 22  ┆ … ┆ 1826     ┆ 20   ┆ 7      ┆ 2013-07-23T00:00:00Z │
# │ ACK  ┆ 2013 ┆ 7     ┆ 23  ┆ … ┆ 199      ┆ 8    ┆ 0      ┆ 2013-07-23T12:00:00Z │
# │ ALB  ┆ 2013 ┆ 1     ┆ 25  ┆ … ┆ 143      ┆ 20   ┆ 0      ┆ 2013-01-26T01:00:00Z │
# │ ANC  ┆ 2013 ┆ 8     ┆ 17  ┆ … ┆ 3370     ┆ 16   ┆ 25     ┆ 2013-08-17T20:00:00Z │
# │ ATL  ┆ 2013 ┆ 7     ┆ 22  ┆ … ┆ 762      ┆ 7    ┆ 59     ┆ 2013-07-22T11:00:00Z │
# │ …    ┆ …    ┆ …     ┆ …   ┆ … ┆ …        ┆ …    ┆ …      ┆ …                    │
# ...

# %%
daily = (
    flights
        .group_by("year", "month", "day")
)

# %%
daily_flights = daily.summarize(n=pl.len())
daily_flights
# Out:
# shape: (365, 4)
# ┌──────┬───────┬─────┬─────┐
# │ year ┆ month ┆ day ┆ n   │
# │ ---  ┆ ---   ┆ --- ┆ --- │
# │ i64  ┆ i64   ┆ i64 ┆ u32 │
# ╞══════╪═══════╪═════╪═════╡
# │ 2013 ┆ 1     ┆ 1   ┆ 842 │
# │ 2013 ┆ 1     ┆ 2   ┆ 943 │
# │ 2013 ┆ 1     ┆ 3   ┆ 914 │
# │ 2013 ┆ 1     ┆ 4   ┆ 915 │
# │ 2013 ┆ 1     ┆ 5   ┆ 720 │
# │ …    ┆ …     ┆ …   ┆ …   │
# │ 2013 ┆ 9     ┆ 26  ┆ 996 │
# │ 2013 ┆ 9     ┆ 27  ┆ 996 │
# │ 2013 ┆ 9     ┆ 28  ┆ 682 │
# │ 2013 ┆ 9     ┆ 29  ┆ 914 │
# │ 2013 ┆ 9     ┆ 30  ┆ 993 │
# └──────┴───────┴─────┴─────┘

# %%
daily.ungroup()
# Out:
# shape: (336_776, 19)
# ┌──────┬───────┬─────┬──────────┬───┬──────────┬──────┬────────┬──────────────────────┐
# │ year ┆ month ┆ day ┆ dep_time ┆ … ┆ distance ┆ hour ┆ minute ┆ time_hour            │
# │ ---  ┆ ---   ┆ --- ┆ ---      ┆   ┆ ---      ┆ ---  ┆ ---    ┆ ---                  │
# │ i64  ┆ i64   ┆ i64 ┆ f64      ┆   ┆ i64      ┆ i64  ┆ i64    ┆ str                  │
# ╞══════╪═══════╪═════╪══════════╪═══╪══════════╪══════╪════════╪══════════════════════╡
# │ 2013 ┆ 1     ┆ 1   ┆ 517.0    ┆ … ┆ 1400     ┆ 5    ┆ 15     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 533.0    ┆ … ┆ 1416     ┆ 5    ┆ 29     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 542.0    ┆ … ┆ 1089     ┆ 5    ┆ 40     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 544.0    ┆ … ┆ 1576     ┆ 5    ┆ 45     ┆ 2013-01-01T10:00:00Z │
# │ 2013 ┆ 1     ┆ 1   ┆ 554.0    ┆ … ┆ 762      ┆ 6    ┆ 0      ┆ 2013-01-01T11:00:00Z │
# ...

# %%
daily.ungroup().summarize(
    avg_delay=pl.col("dep_delay").mean(),
    flights=pl.len()
)
# Out:
# shape: (1, 2)
# ┌───────────┬─────────┐
# │ avg_delay ┆ flights │
# │ ---       ┆ ---     │
# │ f64       ┆ u32     │
# ╞═══════════╪═════════╡
# │ 12.63907  ┆ 336776  │
# └───────────┴─────────┘

# %%
flights.summarize(
    delay=pl.col("dep_delay").mean(),
    n=pl.len(),
    _by="month"
)
# Out:
# shape: (12, 3)
# ┌───────┬───────────┬───────┐
# │ month ┆ delay     ┆ n     │
# │ ---   ┆ ---       ┆ ---   │
# │ i64   ┆ f64       ┆ u32   │
# ╞═══════╪═══════════╪═══════╡
# │ 1     ┆ 10.036665 ┆ 27004 │
# │ 10    ┆ 6.243988  ┆ 28889 │
# │ 11    ┆ 5.435362  ┆ 27268 │
# │ 12    ┆ 16.576688 ┆ 28135 │
# │ 2     ┆ 10.816843 ┆ 24951 │
# │ …     ┆ …         ┆ …     │
# │ 5     ┆ 12.986859 ┆ 28796 │
# │ 6     ┆ 20.846332 ┆ 28243 │
# │ 7     ┆ 21.727787 ┆ 29425 │
# │ 8     ┆ 12.61104  ┆ 29327 │
# │ 9     ┆ 6.722476  ┆ 27574 │
# └───────┴───────────┴───────┘

# %%
flights.summarize(
    delay=pl.col("dep_delay").mean(),
    n=pl.len(),
    _by=["origin", "dest"]
)
# Out:
# shape: (224, 4)
# ┌────────┬──────┬───────────┬───────┐
# │ origin ┆ dest ┆ delay     ┆ n     │
# │ ---    ┆ ---  ┆ ---       ┆ ---   │
# │ str    ┆ str  ┆ f64       ┆ u32   │
# ╞════════╪══════╪═══════════╪═══════╡
# │ EWR    ┆ IAH  ┆ 11.826551 ┆ 3973  │
# │ LGA    ┆ IAH  ┆ 9.058986  ┆ 2951  │
# │ JFK    ┆ MIA  ┆ 9.336571  ┆ 3314  │
# │ JFK    ┆ BQN  ┆ 6.665546  ┆ 599   │
# │ LGA    ┆ ATL  ┆ 11.448621 ┆ 10263 │
# │ …      ┆ …    ┆ …         ┆ …     │
# │ LGA    ┆ TVC  ┆ 23.410959 ┆ 77    │
# │ LGA    ┆ MYR  ┆ 0.666667  ┆ 3     │
# │ EWR    ┆ TVC  ┆ 17.869565 ┆ 24    │
# │ EWR    ┆ ANC  ┆ 12.875    ┆ 8     │
# │ EWR    ┆ LGA  ┆ null      ┆ 1     │
# └────────┴──────┴───────────┴───────┘

# %% [markdown]
# ### Chapter 5

# %%
table1 = hea.data("table1", package="tidyr")
table2 = hea.data("table2", package="tidyr")
table3 = hea.data("table3", package="tidyr")

# %%
table1.mutate(rate=pl.col("cases") / pl.col("population") * 10_000)
# Out:
# shape: (6, 5)
# ┌─────────────┬──────┬────────┬────────────┬──────────┐
# │ country     ┆ year ┆ cases  ┆ population ┆ rate     │
# │ ---         ┆ ---  ┆ ---    ┆ ---        ┆ ---      │
# │ str         ┆ i64  ┆ i64    ┆ i64        ┆ f64      │
# ╞═════════════╪══════╪════════╪════════════╪══════════╡
# │ Afghanistan ┆ 1999 ┆ 745    ┆ 19987071   ┆ 0.372741 │
# │ Afghanistan ┆ 2000 ┆ 2666   ┆ 20595360   ┆ 1.294466 │
# │ Brazil      ┆ 1999 ┆ 37737  ┆ 172006362  ┆ 2.19393  │
# │ Brazil      ┆ 2000 ┆ 80488  ┆ 174504898  ┆ 4.612363 │
# │ China       ┆ 1999 ┆ 212258 ┆ 1272915272 ┆ 1.667495 │
# │ China       ┆ 2000 ┆ 213766 ┆ 1280428583 ┆ 1.669488 │
# └─────────────┴──────┴────────┴────────────┴──────────┘

# %%
table1.group_by("year").summarize(total_cases=pl.col("cases").sum())
# Out:
# shape: (2, 2)
# ┌──────┬─────────────┐
# │ year ┆ total_cases │
# │ ---  ┆ ---         │
# │ i64  ┆ i64         │
# ╞══════╪═════════════╡
# │ 1999 ┆ 250740      │
# │ 2000 ┆ 296920      │
# └──────┴─────────────┘

# %%
billboard = hea.data("billboard", "tidyr")
billboard
# Out:
# shape: (317, 79)
# ┌──────────────────┬─────────────────────────┬──────────────┬─────┬───┬──────┬──────┬──────┬──────┐
# │ artist           ┆ track                   ┆ date.entered ┆ wk1 ┆ … ┆ wk73 ┆ wk74 ┆ wk75 ┆ wk76 │
# │ ---              ┆ ---                     ┆ ---          ┆ --- ┆   ┆ ---  ┆ ---  ┆ ---  ┆ ---  │
# │ str              ┆ str                     ┆ str          ┆ i64 ┆   ┆ f64  ┆ f64  ┆ f64  ┆ f64  │
# ╞══════════════════╪═════════════════════════╪══════════════╪═════╪═══╪══════╪══════╪══════╪══════╡
# │ 2 Pac            ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ 87  ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ 2Ge+her          ┆ The Hardest Part Of ... ┆ 2000-09-02   ┆ 91  ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ 3 Doors Down     ┆ Kryptonite              ┆ 2000-04-08   ┆ 81  ┆ … ┆ null ┆ null ┆ null ┆ null │
# │ 3 Doors Down     ┆ Loser                   ┆ 2000-10-21   ┆ 76  ┆ … ┆ null ┆ null ┆ null ┆ null │
# ...

# %%
billboard.pivot_longer(
    cols=pl.selectors.starts_with("wk"),
    names_to="week",
    values_to="rank",
)
# Out:
# shape: (24_092, 5)
# ┌─────────────────┬─────────────────────────┬──────────────┬──────┬──────┐
# │ artist          ┆ track                   ┆ date.entered ┆ week ┆ rank │
# │ ---             ┆ ---                     ┆ ---          ┆ ---  ┆ ---  │
# │ str             ┆ str                     ┆ str          ┆ str  ┆ f64  │
# ╞═════════════════╪═════════════════════════╪══════════════╪══════╪══════╡
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk1  ┆ 87.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk2  ┆ 82.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk3  ┆ 72.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk4  ┆ 77.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk5  ┆ 87.0 │
# │ …               ┆ …                       ┆ …            ┆ …    ┆ …    │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ wk72 ┆ null │
# ...

# %%
billboard.pivot_longer(
    cols=pl.selectors.starts_with("wk"),
    names_to="week",
    values_to="rank",
    values_drop_na=True,
)
# Out:
# shape: (5_307, 5)
# ┌─────────────────┬─────────────────────────┬──────────────┬──────┬──────┐
# │ artist          ┆ track                   ┆ date.entered ┆ week ┆ rank │
# │ ---             ┆ ---                     ┆ ---          ┆ ---  ┆ ---  │
# │ str             ┆ str                     ┆ str          ┆ str  ┆ f64  │
# ╞═════════════════╪═════════════════════════╪══════════════╪══════╪══════╡
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk1  ┆ 87.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk2  ┆ 82.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk3  ┆ 72.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk4  ┆ 77.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ wk5  ┆ 87.0 │
# │ …               ┆ …                       ┆ …            ┆ …    ┆ …    │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ wk35 ┆ 33.0 │
# ...

# %%
billboard_longer = (
    billboard.pivot_longer(
        cols=pl.selectors.starts_with("wk"),
        names_to="week",
        values_to="rank",
        values_drop_na=True,
        names_prefix="wk",
    ).mutate(
        week=pl.col("week").cast(pl.Int64)
    )
)

# %%
billboard_longer
# Out:
# shape: (5_307, 5)
# ┌─────────────────┬─────────────────────────┬──────────────┬──────┬──────┐
# │ artist          ┆ track                   ┆ date.entered ┆ week ┆ rank │
# │ ---             ┆ ---                     ┆ ---          ┆ ---  ┆ ---  │
# │ str             ┆ str                     ┆ str          ┆ i64  ┆ f64  │
# ╞═════════════════╪═════════════════════════╪══════════════╪══════╪══════╡
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ 1    ┆ 87.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ 2    ┆ 82.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ 3    ┆ 72.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ 4    ┆ 77.0 │
# │ 2 Pac           ┆ Baby Don't Cry (Keep... ┆ 2000-02-26   ┆ 5    ┆ 87.0 │
# │ …               ┆ …                       ┆ …            ┆ …    ┆ …    │
# │ matchbox twenty ┆ Bent                    ┆ 2000-04-29   ┆ 35   ┆ 33.0 │
# ...

# %%
who2 = hea.data("who2", "tidyr")
who2
# Out:
# shape: (7_240, 58)
# ┌─────────────┬──────┬──────────┬───────────┬───┬────────────┬────────────┬────────────┬──────────┐
# │ country     ┆ year ┆ sp_m_014 ┆ sp_m_1524 ┆ … ┆ rel_f_3544 ┆ rel_f_4554 ┆ rel_f_5564 ┆ rel_f_65 │
# │ ---         ┆ ---  ┆ ---      ┆ ---       ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---      │
# │ str         ┆ i64  ┆ f64      ┆ f64       ┆   ┆ f64        ┆ f64        ┆ f64        ┆ f64      │
# ╞═════════════╪══════╪══════════╪═══════════╪═══╪════════════╪════════════╪════════════╪══════════╡
# │ Afghanistan ┆ 1980 ┆ null     ┆ null      ┆ … ┆ null       ┆ null       ┆ null       ┆ null     │
# │ Afghanistan ┆ 1981 ┆ null     ┆ null      ┆ … ┆ null       ┆ null       ┆ null       ┆ null     │
# │ Afghanistan ┆ 1982 ┆ null     ┆ null      ┆ … ┆ null       ┆ null       ┆ null       ┆ null     │
# │ Afghanistan ┆ 1983 ┆ null     ┆ null      ┆ … ┆ null       ┆ null       ┆ null       ┆ null     │
# ...

# %%
(
    who2
        .pivot_longer(
            cols=pl.exclude(who2.cols_between("country", "year")),
            names_to=["diagnosis", "gender", "age"],
            names_sep="_",
            values_to="count",
        )
)
# Out:
# shape: (405_440, 6)
# ┌─────────────┬──────┬────────┬───────────┬────────┬──────┐
# │ country     ┆ year ┆ count  ┆ diagnosis ┆ gender ┆ age  │
# │ ---         ┆ ---  ┆ ---    ┆ ---       ┆ ---    ┆ ---  │
# │ str         ┆ i64  ┆ f64    ┆ str       ┆ str    ┆ str  │
# ╞═════════════╪══════╪════════╪═══════════╪════════╪══════╡
# │ Afghanistan ┆ 1980 ┆ null   ┆ sp        ┆ m      ┆ 014  │
# │ Afghanistan ┆ 1980 ┆ null   ┆ sp        ┆ m      ┆ 1524 │
# │ Afghanistan ┆ 1980 ┆ null   ┆ sp        ┆ m      ┆ 2534 │
# │ Afghanistan ┆ 1980 ┆ null   ┆ sp        ┆ m      ┆ 3544 │
# │ Afghanistan ┆ 1980 ┆ null   ┆ sp        ┆ m      ┆ 4554 │
# │ …           ┆ …    ┆ …      ┆ …         ┆ …      ┆ …    │
# │ Zimbabwe    ┆ 2013 ┆ 4649.0 ┆ rel       ┆ f      ┆ 2534 │
# │ Zimbabwe    ┆ 2013 ┆ 3526.0 ┆ rel       ┆ f      ┆ 3544 │
# │ Zimbabwe    ┆ 2013 ┆ 1453.0 ┆ rel       ┆ f      ┆ 4554 │
# │ Zimbabwe    ┆ 2013 ┆ 811.0  ┆ rel       ┆ f      ┆ 5564 │
# ...

# %%
household = hea.data("household", "tidyr")
household
# Out:
# shape: (5, 5)
# ┌────────┬────────────┬────────────┬─────────────┬─────────────┐
# │ family ┆ dob_child1 ┆ dob_child2 ┆ name_child1 ┆ name_child2 │
# │ ---    ┆ ---        ┆ ---        ┆ ---         ┆ ---         │
# │ i64    ┆ str        ┆ str        ┆ str         ┆ str         │
# ╞════════╪════════════╪════════════╪═════════════╪═════════════╡
# │ 1      ┆ 1998-11-26 ┆ 2000-01-29 ┆ Susan       ┆ Jose        │
# │ 2      ┆ 1996-06-22 ┆ null       ┆ Mark        ┆ null        │
# │ 3      ┆ 2002-07-11 ┆ 2004-04-05 ┆ Sam         ┆ Seth        │
# │ 4      ┆ 2004-10-10 ┆ 2009-08-27 ┆ Craig       ┆ Khai        │
# │ 5      ┆ 2000-12-05 ┆ 2005-02-28 ┆ Parker      ┆ Gracie      │
# └────────┴────────────┴────────────┴─────────────┴─────────────┘

# %%
(
    household
        .pivot_longer(
            cols=pl.exclude("family"),
            names_to=[".value", "child"],
            names_sep="_",
            values_drop_na=True,
        )
)
# Out:
# shape: (9, 4)
# ┌────────┬────────┬────────────┬────────┐
# │ family ┆ child  ┆ dob        ┆ name   │
# │ ---    ┆ ---    ┆ ---        ┆ ---    │
# │ i64    ┆ str    ┆ str        ┆ str    │
# ╞════════╪════════╪════════════╪════════╡
# │ 1      ┆ child1 ┆ 1998-11-26 ┆ Susan  │
# │ 1      ┆ child2 ┆ 2000-01-29 ┆ Jose   │
# │ 2      ┆ child1 ┆ 1996-06-22 ┆ Mark   │
# │ 3      ┆ child1 ┆ 2002-07-11 ┆ Sam    │
# │ 3      ┆ child2 ┆ 2004-04-05 ┆ Seth   │
# │ 4      ┆ child1 ┆ 2004-10-10 ┆ Craig  │
# │ 4      ┆ child2 ┆ 2009-08-27 ┆ Khai   │
# │ 5      ┆ child1 ┆ 2000-12-05 ┆ Parker │
# │ 5      ┆ child2 ┆ 2005-02-28 ┆ Gracie │
# └────────┴────────┴────────────┴────────┘

# %%
exp = hea.data("cms_patient_experience", "tidyr")
exp
# Out:
# shape: (500, 5)
# ┌────────────┬─────────────────────────────┬──────────────┬─────────────────────────────┬──────────┐
# │ org_pac_id ┆ org_nm                      ┆ measure_cd   ┆ measure_title               ┆ prf_rate │
# │ ---        ┆ ---                         ┆ ---          ┆ ---                         ┆ ---      │
# │ i64        ┆ str                         ┆ str          ┆ str                         ┆ f64      │
# ╞════════════╪═════════════════════════════╪══════════════╪═════════════════════════════╪══════════╡
# │ 446157747  ┆ USC CARE MEDICAL GROUP INC  ┆ CAHPS_GRP_1  ┆ CAHPS for MIPS SSM: Getting ┆ 63.0     │
# │            ┆                             ┆              ┆ Ti…                         ┆          │
# │ 446157747  ┆ USC CARE MEDICAL GROUP INC  ┆ CAHPS_GRP_2  ┆ CAHPS for MIPS SSM: How     ┆ 87.0     │
# │            ┆                             ┆              ┆ Well P…                     ┆          │
# ...

# %%
(
    exp
        .distinct("measure_cd", "measure_title")
)
# Out:
# shape: (6, 2)
# ┌──────────────┬─────────────────────────────────┐
# │ measure_cd   ┆ measure_title                   │
# │ ---          ┆ ---                             │
# │ str          ┆ str                             │
# ╞══════════════╪═════════════════════════════════╡
# │ CAHPS_GRP_1  ┆ CAHPS for MIPS SSM: Getting Ti… │
# │ CAHPS_GRP_2  ┆ CAHPS for MIPS SSM: How Well P… │
# │ CAHPS_GRP_3  ┆ CAHPS for MIPS SSM: Patient's … │
# │ CAHPS_GRP_5  ┆ CAHPS for MIPS SSM: Health Pro… │
# │ CAHPS_GRP_8  ┆ CAHPS for MIPS SSM: Courteous … │
# │ CAHPS_GRP_12 ┆ CAHPS for MIPS SSM: Stewardshi… │
# └──────────────┴─────────────────────────────────┘

# %%
(
    exp.
        pivot_wider(
            names_from="measure_cd",
            values_from="prf_rate"
        )
)
# Out:
# shape: (500, 9)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ org_pac_i ┆ org_nm    ┆ measure_t ┆ CAHPS_GRP ┆ … ┆ CAHPS_GRP ┆ CAHPS_GRP ┆ CAHPS_GRP ┆ CAHPS_GR │
# │ d         ┆ ---       ┆ itle      ┆ _1        ┆   ┆ _3        ┆ _5        ┆ _8        ┆ P_12     │
# │ ---       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ i64       ┆           ┆ str       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 446157747 ┆ USC CARE  ┆ CAHPS for ┆ 63.0      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆ MEDICAL   ┆ MIPS SSM: ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ GROUP INC ┆ Getting   ┆           ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
(
    exp.
        pivot_wider(
            id_cols=pl.selectors.starts_with("org"),
            names_from="measure_cd",
            values_from="prf_rate"
        )
)
# Out:
# shape: (95, 8)
# ┌────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬───────────┬───────────┐
# │ org_pac_id ┆ org_nm     ┆ CAHPS_GRP_ ┆ CAHPS_GRP ┆ CAHPS_GRP ┆ CAHPS_GRP ┆ CAHPS_GRP ┆ CAHPS_GRP │
# │ ---        ┆ ---        ┆ 1          ┆ _2        ┆ _3        ┆ _5        ┆ _8        ┆ _12       │
# │ i64        ┆ str        ┆ ---        ┆ ---       ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │            ┆            ┆ f64        ┆ f64       ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 446157747  ┆ USC CARE   ┆ 63.0       ┆ 87.0      ┆ 86.0      ┆ 57.0      ┆ 85.0      ┆ 24.0      │
# │            ┆ MEDICAL    ┆            ┆           ┆           ┆           ┆           ┆           │
# │            ┆ GROUP INC  ┆            ┆           ┆           ┆           ┆           ┆           │
# ...
